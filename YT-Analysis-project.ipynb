# %%
from googleapiclient.discovery import build

# %%
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyBl3mOwWVib4adXmfN4UHCVZ6SOkuetWL0'
channel_ids = ['UCoOae5nYA7VqaXzerajD0lg',
             'UCnz-ZXXER4jOvuED5trXfEA','UCCWi3hpnq_Pe03nGxuS7isg',
             'UC3rY5HOgbBvGmq7RnDfwF7A',
               'UC7cs8q-gJRlGwj4A8OmCmXg','UCh9nVJoWXmFb7sLApWGcLPQ',
               'UCJQJAI7IjbLcpsjWdSzYz0Q','UCNGIDQ466bNY87eEeKeQuzA',
               'UCNGIDQ466bNY87eEeKeQuzA','UC5fs7PookxGfDPTo-RU0ReQ',
               'UCsvqVGtbbyHaMoevxPAq9Fg'
             ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_id):
    
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id= channel_id)
    response = request.execute()
    
    return response

# %%
get_channel_stats(youtube, channel_id)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'l__NyURG_bcqceYo9X7Vsd9qRD0',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'ktKTzDevs7Q4LszUmn1UWlYZ41w',
#    'id': 'UCoOae5nYA7VqaXzerajD0lg',
#    'snippet': {'title': 'Ali Abdaal',
#     'description': "Check out my new book Feel-Good Productivity at the link below! 📚\n\nhttps://www.feelgoodproductivity.com/?utm_campaign=preorder&utm_source=youtubeaboutpage&utm_medium=aboutpage\n\nHey, I'm Ali, a doctor turned entrepreneur, and the world’s most followed productivity expert 😜 \n\nOn this channel, we explore evidence-based strategies and tools that can help us be more productive, and build a life that we love. \n\nIf that sounds interesting, consider subscribing! See you in the next video x",
#     'customUrl': '@aliabdaal',
#     'publishedAt': '2007-11-20T18:53:34Z',
# ...

# %%
from IPython.display import JSON

# %%
api_key = 'AIzaSyBl3mOwWVib4adXmfN4UHCVZ6SOkuetWL0'

api_service_name = "youtube"
api_version = "v3"

    # Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=''.join(channel_id)
    )
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'l__NyURG_bcqceYo9X7Vsd9qRD0', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'ktKTzDevs7Q4LszUmn1UWlYZ41w', 'id': 'UCoOae5nYA7VqaXzerajD0lg', 'snippet': {'title': 'Ali Abdaal', 'description': "Check out my new book Feel-Good Productivity at the link below! 📚\n\nhttps://www.feelgoodproductivity.com/?utm_campaign=preorder&utm_source=youtubeaboutpage&utm_medium=aboutpage\n\nHey, I'm Ali, a doctor turned entrepreneur, and the world’s most followed productivity expert 😜 \n\nOn this channel, we explore evidence-based strategies and tools that can help us be more productive, and build a life that we love. \n\nIf that sounds interesting, consider subscribing! See you in the next video x", 'customUrl': '@aliabdaal', 'publishedAt': '2007-11-20T18:53:34Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZQp3RlH9XwcrLuWjVqpjsfE9esXbLztrfMQkVWz=s88-c-k-c0x00ffffff-no-rj', 'width
# ...

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id= ','.join(channel_ids)
    )
    
    response = request.execute()
    
    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
               }
    
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
get_channel_stats(youtube, channel_ids)
# Out:
#              channelName subscribers      views totalVideos  \
# 0             Ali Abdaal     5180000  396743303         815
# 1             codebasics      936000   67586320         800
# 2       Alex The Analyst      690000   29595453         281
# 3                techTFQ      266000   14208604         102
# 4          Pavan Lalwani      162000   13370301         302
# 5  Thu Vu data analytics      197000    6592893          81
# 6         Rishabh Mishra      193000   11240648          85
# 7             360DigiTMG       63400    2712266        2383
# 8                CampusX      159000   16432221        1164
# 9            Simplilearn     3680000  331176608        7152
#
#                  playlistId
# 0  UUoOae5nYA7VqaXzerajD0lg
# 1  UUh9nVJoWXmFb7sLApWGcLPQ
# 2  UU7cs8q-gJRlGwj4A8OmCmXg
# 3  UUnz-ZXXER4jOvuED5trXfEA
# 4  UU5fs7PookxGfDPTo-RU0ReQ
# 5  UUJQJAI7IjbLcpsjWdSzYz0Q
# 6  UU3rY5HOgbBvGmq7RnDfwF7A
# 7  UUNGIDQ466bNY87eEeKeQuzA
# 8  UUCWi3hpnq_Pe03nGxuS7isg
# ...

# %%
Youtube_data = get_channel_stats(youtube, channel_ids)

# %%
Youtube_data.dtypes
# Out:
# channelName    object
# subscribers    object
# views          object
# totalVideos    object
# playlistId     object
# dtype: object

# %%
Youtube_data['subscribers']=pd.to_numeric(Youtube_data['subscribers'])
Youtube_data['views']=pd.to_numeric(Youtube_data['views'])
Youtube_data['totalVideos']=pd.to_numeric(Youtube_data['totalVideos'])

# %%
Youtube_data.dtypes
# Out:
# channelName    object
# subscribers     int64
# views           int64
# totalVideos     int64
# playlistId     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(20,10)})
ax=sns.barplot(x='channelName',y='subscribers',data=Youtube_data)

# %%
ax=sns.barplot(x='channelName',y='views',data=Youtube_data)

# %%
ax=sns.barplot(x='channelName',y='totalVideos',data=Youtube_data)

# %% [markdown]
# ## Scrape, Analyze & Visualize Video Details
